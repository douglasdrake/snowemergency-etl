# %% [markdown]
# # ETL for the Grant 2015 Snow Emergency Tows Data Set
# The .CSV file for the Grant 2015 Snow Emergency does not contain the latitudes and longitudes of the towing incidents.  The GeoJSON file does include this information.  We can use a GeoPandas GeoDataFrame to manipulate this GeoJSON to extract the longitude and latitude information.  We perform the following steps:
#
# 1.  Fill missing coordinates by using Google Places to geocode the given address information.
# 2.  Fill missing Ward, Community, and Neighborhood information in using shapely's `polygon.contains(point)` functionality.  We have GeoJSONs with the boundaries for Minneapolis Wards, Communities, and Neighborhoods.  For each point, we can write a function that returns the corresponding Ward, Community, and Neighborhood.
# 3.  Extract the GeoDataFrame to an ordinary Pandas DataFrame by dropping the geometry column to a pair of columns: latitude and longitude.
# 4.  Split the datetime string into a date and time field.
# 5.  Write the final data frame to a `.csv` file to be combined with the other cleaned files.

# %%
# import the dependencies
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import geopy

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from geopy.geocoders import GoogleV3

from api_keys import api_key

# %%
# constants related to input and output

DATA_DIR = "data"
GRANT_FILE = "Snow_Emergency_Grant_Tows_2015.geojson"
OUTPUT_DIR = "output"
WARDS_FILE = "City_Council_Wards.geojson"
COMMUNITIES_FILE = "Communities.geojson"
NEIGHBORHOODS_FILE = "Minneapolis_Neighborhoods.geojson"
OUTPUT_FILE = "Grant_Tows.csv"

# %%
# a helper function to read files in.  GeoPandas read_file can load GeoJSONs

def load_data(filename, data_dir=DATA_DIR):
    filepath = os.path.join(data_dir, filename)
    return gpd.read_file(filepath)

# %%
grant_tows = load_data(GRANT_FILE)
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day                                      geometry
# 0     2326 Central Ave NE  Day 1  POINT (-93.24740688343616 45.01123618428048)
# 1               618 1ST N  Day 1  POINT (-93.27510825313226 44.97945116173709)
# 2          1824 3rd ave s  Day 1  POINT (-93.27281155185176 44.96488946723947)
# 3  2519 bloomington ave s  Day 1  POINT (-93.25235251858196 44.95697462618004)
# 4     3447 Central Ave NE  Day 1  POINT (-93.24719240972475 45.03026988637581)

# %%
grant_tows.shape
# Out:
# (1736, 7)

# %% [markdown]
# # 1.  Fill in Missing Geometries

# %%
# how many observations are missing geometry?
grant_tows.geometry.isnull().sum()
# Out:
# 180

# %%
# prepare to geocode missing geometries:
geolocator = GoogleV3(api_key=api_key)

# %%
# Loop over the GeoDataFrame, if the geometry is missing geocode from the Location
import time

for idx in range(grant_tows.shape[0]):
    if not grant_tows.loc[idx, 'geometry']:
        address = grant_tows.loc[idx, 'Location'] + ", Minneapolis, MN"
        print(address)
        result =  geolocator.geocode(address)
        geom = Point(result.longitude, result.latitude)
        time.sleep(2) # avoid the API rate limit
        grant_tows.loc[idx, 'geometry'] = geom
# Out:
# University and 8th ave, Minneapolis, MN
# 395 2nd st s e, Minneapolis, MN
# NE Grand & Lowry, Minneapolis, MN
# 528 e 15th st, Minneapolis, MN
# Grand & Lowry, Minneapolis, MN
# 1923 1rst st s, Minneapolis, MN
# E 16th st/ Chicago, Minneapolis, MN
# 3330 Fremont, Minneapolis, MN
# Grand & Lowry, Minneapolis, MN
# 2321 n 2nd st, Minneapolis, MN
# 3550 E 46TH ST, Minneapolis, MN
# 528 e15th st, Minneapolis, MN
# 4th and 8th, Minneapolis, MN
# 604 e15th st, Minneapolis, MN
# 503 E 15th St, Minneapolis, MN
# 3540, Minneapolis, MN
# 408 erie nd ave se, Minneapolis, MN
# 1416 e 41st st, Minneapolis, MN
# 2418  N 3rd st, Minneapolis, MN
# 15th / oak grove, Minneapolis, MN
# 801 n. washington ave., Minneapolis, MN
# 17th como ave s e, Minneapolis, MN
# 13th Ave & Grand, Minneapolis, MN
# 13th Ave & Grand, Minneapolis, MN
# 2752 e 38 st, Minneapolis, MN
# 916 N Washington Ave, Minneapolis, MN
# 13th Ave & Grand, Minneapolis, MN
# 2205 blaisdell s, Minneapolis, MN
# 2245 blaidsdell ave, Minneapolis, MN
# rear, Minneapolis, MN
# 2311 blaisedale s, Minneapolis, MN
# 829 3rd st n space no. 1829, Minneapolis, MN
# 507 e 15th st, Minneapolis, MN
# 507 E 15th St, Minneapolis, MN
# Minneapolis, Minneapolis, MN
# University and 8, Minneapolis, MN
# 656 e 15th, Minneapolis, MN
# 13 Ave NE, Minneapolis, MN
# 3614 Fremont, Minneapolis, MN
# 2408 blaisdale, Minneapolis, MN
# 800 n Washington ave, Minneapolis, MN
# 4349 28th, Minneapolis, MN
# 1726 e 15th st, Minneapolis, MN
# Franklin/ blaisdale, Minneapolis, MN
# 15th ave se, Minneapolis, MN
# 2518 Fremont ave n Minneapolis, Minneapolis, MN
# 726 E 15TH ST, Minneapolis, MN
# E 16th/ Chicago, Minneapolis, MN
# 726 E 15TH ST, Minneapolis, MN
# 606 e 15th st, Minneapolis, MN
# 1300. Blk harmon pl, Minneapolis, MN
# 2106 Fremont ace n Minneapolis, Minneapolis, MN
# 2427 blaisdell s, Minneapolis, MN
# 2511 CHICAGO AVE A, Minneapolis, MN
# 4729 2oth ave so, Minneapolis, MN
# 4130 Fremont ave n Minneapolis, Minneapolis, MN
# 2678 WEST 43RD ST, Minneapolis, MN
# 14th&LaSalle Ave, Minneapolis, MN
# 13th & Grand, Minneapolis, MN
# 2570 W 43rd ST, Minneapolis, MN
# Walnut st se and Delaware, Minneapolis, MN
# 2727 44st w, Minneapolis, MN
# 15th/ lasalle, Minneapolis, MN
# 13 ave se, Minneapolis, MN
# 1521 lascell, Minneapolis, MN
# 1230 8th st s e, Minneapolis, MN
# 3915 Fremont ace n Minneapolis, Minneapolis, MN
# 2498 blaisdale, Minneapolis, MN
# 26th/ blaisdale, Minneapolis, MN
# 2697 Blas dale ave s, Minneapolis, MN
# 2663 blaidsdell, Minneapolis, MN
# 672 e 15th  st, Minneapolis, MN
# S 19th and Franklin f rd, Minneapolis, MN
# 2552 w 43rd st, Minneapolis, MN
# 1575 lesalle ave s, Minneapolis, MN
# 1545 le salle Ave s, Minneapolis, MN
# 2707 blaisdale, Minneapolis, MN
# Mncis parking, Minneapolis, MN
# 726 e 15th, Minneapolis, MN
# 43rd/upton, Minneapolis, MN
# 13th & Marshall, Minneapolis, MN
# 907 19tg ave s, Minneapolis, MN
# 1430 lesalle, Minneapolis, MN
# 2200 N 4th st, Minneapolis, MN
# 2312 N 4th st, Minneapolis, MN
# 1100 uptown  Ave N, Minneapolis, MN
# 2322 N 4th st, Minneapolis, MN
# 900 Iving Ave N, Minneapolis, MN
# 1104 14 th ave s e, Minneapolis, MN
# 1914 Clinton ace s, Minneapolis, MN
# 3404 Holmes, Minneapolis, MN
# 3532 Holmes, Minneapolis, MN
# 1220 GRAND ST NE, Minneapolis, MN
# 1217 talmage ave s e, Minneapolis, MN
# 3112 Holmes, Minneapolis, MN
# 128 9th ave ne, Minneapolis, MN
# 2318 N 4th st, Minneapolis, MN
# 2222 N 4th st, Minneapolis, MN
# 2214 N 4th st, Minneapolis, MN
# 3118 Holmes, Minneapolis, MN
# 3554 Holmes, Minneapolis, MN
# 2210 N 4th st, Minneapolis, MN
# 1047 13th ave s e, Minneapolis, MN
# 3217 HOLMES, Minneapolis, MN
# 1033 16th ave s e, Minneapolis, MN
# 421 giarad ter, Minneapolis, MN
# 638 pol st ne, Minneapolis, MN
# 1502 e 33rd st, Minneapolis, MN
# 3228 15th a ve s, Minneapolis, MN
# 1108 14th ave s e, Minneapolis, MN
# 3142 16tj ave, Minneapolis, MN
# 204 E 18th st, Minneapolis, MN
# 612 Knox ave n, Minneapolis, MN
# 1518 5th st s.e., Minneapolis, MN
# 1048 16th ave s e, Minneapolis, MN
# 1074 14th ave s e, Minneapolis, MN
# 1908 Neuton Ave N, Minneapolis, MN
# 1056 24th ave s e, Minneapolis, MN
# 1329 7 th se, Minneapolis, MN
# 7th and 14th ST SE, Minneapolis, MN
# 1015 16th ave s e, Minneapolis, MN
# 84'6 8th Ave n, Minneapolis, MN
# 705 Lyndale place, Minneapolis, MN
# 929 12th ave s e, Minneapolis, MN
# 1101 22nd ave s e, Minneapolis, MN
# 2737 peirce st ne, Minneapolis, MN
# 2653 james abe n, Minneapolis, MN
# 33oak grove st, Minneapolis, MN

# %%
grant_tows.geometry.isnull().sum()
# Out:
# 0

# %%
# Save the work done so far to avoid needing to geocode again:
grant_tows.to_csv(os.path.join(OUTPUT_DIR, "grant_temp.csv"))

# %% [markdown]
# # 2.  Determine Wards, Communities, Neighborhoods

# %%
wards = load_data(WARDS_FILE)
wards.head()
# Out:
#    FID BDNUM    Shape_STAr    Shape_STLe  \
# 0    1     1  2.044159e+08  71797.801731
# 1    2     9  7.290147e+07  42091.446370
# 2    3     3  1.062057e+08  57104.348729
# 3    4     4  1.471704e+08  57462.048968
# 4    5     8  7.869230e+07  47568.406676
#
#                                             geometry
# 0  POLYGON ((-93.2268508021494 45.0132152671148, ...
# 1  POLYGON ((-93.2431848712514 44.955829056264, -...
# 2  POLYGON ((-93.2631316871618 45.0131674841788, ...
# 3  POLYGON ((-93.2991995476941 45.0511367258392, ...
# 4  POLYGON ((-93.2747782291209 44.9483536669077, ...

# %%
# A helper function for determining the ward of a point:

def find_ward(place, wards_df=wards):
    for row in wards_df.itertuples():
        if row.geometry.contains(place):
            return row.BDNUM

# %%
grant_tows['Ward'] = grant_tows.geometry.map(find_ward)

# %%
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day  \
# 0     2326 Central Ave NE  Day 1
# 1               618 1ST N  Day 1
# 2          1824 3rd ave s  Day 1
# 3  2519 bloomington ave s  Day 1
# 4     3447 Central Ave NE  Day 1
#
#                                        geometry Ward
# 0  POINT (-93.24740688343616 45.01123618428048)    1
# 1  POINT (-93.27510825313226 44.97945116173709)    3
# 2  POINT (-93.27281155185176 44.96488946723947)    6
# 3  POINT (-93.25235251858196 44.95697462618004)    9
# 4  POINT (-93.24719240972475 45.03026988637581)    1

# %%
communities = load_data(COMMUNITIES_FILE)
communities.head()
# Out:
#    FID    CommName                                           geometry
# 0    1      Camden  POLYGON ((-93.31949186501051 45.0512462469094,...
# 1    2   Northeast  POLYGON ((-93.22685080614011 45.0132165472863,...
# 2    3  Near North  POLYGON ((-93.3178372365291 45.013260021455, -...
# 3    4     Central  POLYGON ((-93.27211391203549 44.9921313605316,...
# 4    5  University  POLYGON ((-93.2076071706838 45.0015313002637, ...

# %%
# A helper function for determining the community of a point:

def find_community(place, community_df=communities):
    for row in community_df.itertuples():
        if row.geometry.contains(place):
            return row.CommName

# %%
grant_tows['Community'] = grant_tows.geometry.map(find_community)

# %%
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day  \
# 0     2326 Central Ave NE  Day 1
# 1               618 1ST N  Day 1
# 2          1824 3rd ave s  Day 1
# 3  2519 bloomington ave s  Day 1
# 4     3447 Central Ave NE  Day 1
#
#                                        geometry Ward  Community
# 0  POINT (-93.24740688343616 45.01123618428048)    1  Northeast
# 1  POINT (-93.27510825313226 44.97945116173709)    3    Central
# 2  POINT (-93.27281155185176 44.96488946723947)    6    Central
# 3  POINT (-93.25235251858196 44.95697462618004)    9   Phillips
# 4  POINT (-93.24719240972475 45.03026988637581)    1  Northeast

# %%
neighborhoods = load_data(NEIGHBORHOODS_FILE)
neighborhoods.head()
# Out:
#    FID             BDNAME BDNUM TEXT_NBR    Shape_STAr    Shape_STLe  \
# 0    1      Phillips West    90       90  1.066925e+07  14403.885934
# 1    2      Downtown West    87       87  2.075613e+07  19220.602541
# 2    3      Downtown East    88       88  1.025499e+07  13436.601356
# 3    4    Ventura Village    89       89  1.263526e+07  16988.532717
# 4    5  Sumner - Glenwood    29       29  5.741860e+06  11065.343364
#
#                                             NCR_LINK IMAGE  \
# 0  http://www.nrp.org/r2/Neighborhoods/Orgs/PHW.html   PHW
# 1  http://www.nrp.org/r2/Neighborhoods/Orgs/DTN.html   DTN
# 2  http://www.nrp.org/r2/Neighborhoods/Orgs/DTN.html   DTN
# 3  http://www.nrp.org/r2/Neighborhoods/Orgs/VEN.html   VEN
# 4  http://www.nrp.org/r2/Neighborhoods/Orgs/SGL.html   SGL
#
#                                             geometry
# 0  POLYGON ((-93.2625807586419 44.9609082137146, ...
# 1  POLYGON ((-93.2601055025157 44.9829952758614, ...
# 2  POLYGON ((-93.2449864570206 44.9789336625517, ...
# 3  POLYGON ((-93.24957700344829 44.9662967560422,...
# 4  POLYGON ((-93.2882976528817 44.9890356035354, ...

# %%
neighborhoods.shape
# Out:
# (87, 9)

# %%
# A helper function for determining the neighborhood of a point:

def find_neighborhood(place, neighborhood_df=neighborhoods):
    for row in neighborhood_df.itertuples():
        if row.geometry.contains(place):
            return row.BDNAME

# %%
grant_tows['Neighborhood'] = grant_tows.geometry.map(find_neighborhood)
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day  \
# 0     2326 Central Ave NE  Day 1
# 1               618 1ST N  Day 1
# 2          1824 3rd ave s  Day 1
# 3  2519 bloomington ave s  Day 1
# 4     3447 Central Ave NE  Day 1
#
#                                        geometry Ward  Community  \
# 0  POINT (-93.24740688343616 45.01123618428048)    1  Northeast
# 1  POINT (-93.27510825313226 44.97945116173709)    3    Central
# 2  POINT (-93.27281155185176 44.96488946723947)    6    Central
# 3  POINT (-93.25235251858196 44.95697462618004)    9   Phillips
# 4  POINT (-93.24719240972475 45.03026988637581)    1  Northeast
#
#                        Neighborhood
# 0                           Holland
# 1                     Downtown West
# 2  Steven's Square - Loring Heights
# 3                     East Phillips
# 4                        Waite Park

# %%
# Save the work done so far to avoid needing to geocode again:
grant_tows.to_csv(os.path.join(OUTPUT_DIR, "grant_temp.csv"))

# %% [markdown]
# # 3.  Drop the geometry column.  Add two columns for Longitude and Latitude.

# %%
def point_longitude (point):
    return point.x

def point_latitude (point):
    return point.y

grant_tows['Longitude'] = grant_tows['geometry'].x
grant_tows['Latitude'] = grant_tows['geometry'].y
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day  \
# 0     2326 Central Ave NE  Day 1
# 1               618 1ST N  Day 1
# 2          1824 3rd ave s  Day 1
# 3  2519 bloomington ave s  Day 1
# 4     3447 Central Ave NE  Day 1
#
#                                        geometry Ward  Community  \
# 0  POINT (-93.24740688343616 45.01123618428048)    1  Northeast
# 1  POINT (-93.27510825313226 44.97945116173709)    3    Central
# 2  POINT (-93.27281155185176 44.96488946723947)    6    Central
# 3  POINT (-93.25235251858196 44.95697462618004)    9   Phillips
# 4  POINT (-93.24719240972475 45.03026988637581)    1  Northeast
#
#                        Neighborhood  Longitude   Latitude
# 0                           Holland -93.247407  45.011236
# 1                     Downtown West -93.275108  44.979451
# 2  Steven's Square - Loring Heights -93.272812  44.964889
# 3                     East Phillips -93.252353  44.956975
# 4                        Waite Park -93.247192  45.030270

# %% [markdown]
# # 4.  Convert Call_Taken to a Date String and Time String.  Note that the Times are all 00:00:00

# %%
import dateutil.parser as dparser
from datetime import datetime

test = dparser.parse(grant_tows.loc[0, 'Call_Taken'], fuzzy=True)
print(test.strftime("%m/%d/%Y"))
print(test.strftime("%H:%M"))
# Out:
# 12/29/2015
# 00:00

# %%
# A helper function to map against the `Call_Taken` column to get the date

def get_date(call_string):
    call_dt = dparser.parse(call_string, fuzzy=True)
    return call_dt.strftime("%m/%d/%Y")

def get_time(call_string):
    call_dt = dparser.parse(call_string, fuzzy=True)
    return call_dt.strftime("%H:%M")

grant_tows['Date'] = grant_tows.Call_Taken.map(get_date)
grant_tows['Time'] = grant_tows.Call_Taken.map(get_time)
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day  \
# 0     2326 Central Ave NE  Day 1
# 1               618 1ST N  Day 1
# 2          1824 3rd ave s  Day 1
# 3  2519 bloomington ave s  Day 1
# 4     3447 Central Ave NE  Day 1
#
#                                        geometry Ward  Community  \
# 0  POINT (-93.24740688343616 45.01123618428048)    1  Northeast
# 1  POINT (-93.27510825313226 44.97945116173709)    3    Central
# 2  POINT (-93.27281155185176 44.96488946723947)    6    Central
# 3  POINT (-93.25235251858196 44.95697462618004)    9   Phillips
# 4  POINT (-93.24719240972475 45.03026988637581)    1  Northeast
#
#                        Neighborhood  Longitude   Latitude        Date   Time
# 0                           Holland -93.247407  45.011236  12/29/2015  00:00
# 1                     Downtown West -93.275108  44.979451  12/29/2015  00:00
# 2  Steven's Square - Loring Heights -93.272812  44.964889  12/29/2015  00:00
# 3                     East Phillips -93.252353  44.956975  12/29/2015  00:00
# 4                        Waite Park -93.247192  45.030270  12/29/2015  00:00

# %% [markdown]
# # Convert the Day column to an integer - to be uniform with the other data sets.

# %%
grant_tows.Day.unique()
# Out:
# array(['Day 1', 'Day 2', 'Day 3'], dtype=object)

# %%
grant_tows['Day'] = grant_tows.Day.map(lambda x: int(x.split()[1]))
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location  Day                                      geometry  \
# 0     2326 Central Ave NE    1  POINT (-93.24740688343616 45.01123618428048)
# 1               618 1ST N    1  POINT (-93.27510825313226 44.97945116173709)
# 2          1824 3rd ave s    1  POINT (-93.27281155185176 44.96488946723947)
# 3  2519 bloomington ave s    1  POINT (-93.25235251858196 44.95697462618004)
# 4     3447 Central Ave NE    1  POINT (-93.24719240972475 45.03026988637581)
#
#   Ward  Community                      Neighborhood  Longitude   Latitude  \
# 0    1  Northeast                           Holland -93.247407  45.011236
# 1    3    Central                     Downtown West -93.275108  44.979451
# 2    6    Central  Steven's Square - Loring Heights -93.272812  44.964889
# 3    9   Phillips                     East Phillips -93.252353  44.956975
# 4    1  Northeast                        Waite Park -93.247192  45.030270
#
#          Date   Time
# 0  12/29/2015  00:00
# 1  12/29/2015  00:00
# 2  12/29/2015  00:00
# 3  12/29/2015  00:00
# 4  12/29/2015  00:00

# %%
grant_tows_final = pd.DataFrame(grant_tows[['Date', 'Time', 'Location', 'Latitude', 'Longitude', 'Ward', 'Community', 'Neighborhood']])

# %%
grant_tows_final.head()
# Out:
#          Date   Time                Location   Latitude  Longitude Ward  \
# 0  12/29/2015  00:00     2326 Central Ave NE  45.011236 -93.247407    1
# 1  12/29/2015  00:00               618 1ST N  44.979451 -93.275108    3
# 2  12/29/2015  00:00          1824 3rd ave s  44.964889 -93.272812    6
# 3  12/29/2015  00:00  2519 bloomington ave s  44.956975 -93.252353    9
# 4  12/29/2015  00:00     3447 Central Ave NE  45.030270 -93.247192    1
#
#    Community                      Neighborhood
# 0  Northeast                           Holland
# 1    Central                     Downtown West
# 2    Central  Steven's Square - Loring Heights
# 3   Phillips                     East Phillips
# 4  Northeast                        Waite Park

# %%
grant_tows_final['Emergency'] = 'Grant'
grant_tows_final.head()
# Out:
#          Date   Time                Location   Latitude  Longitude Ward  \
# 0  12/29/2015  00:00     2326 Central Ave NE  45.011236 -93.247407    1
# 1  12/29/2015  00:00               618 1ST N  44.979451 -93.275108    3
# 2  12/29/2015  00:00          1824 3rd ave s  44.964889 -93.272812    6
# 3  12/29/2015  00:00  2519 bloomington ave s  44.956975 -93.252353    9
# 4  12/29/2015  00:00     3447 Central Ave NE  45.030270 -93.247192    1
#
#    Community                      Neighborhood Emergency
# 0  Northeast                           Holland     Grant
# 1    Central                     Downtown West     Grant
# 2    Central  Steven's Square - Loring Heights     Grant
# 3   Phillips                     East Phillips     Grant
# 4  Northeast                        Waite Park     Grant

# %%
grant_tows_final.to_csv(os.path.join(OUTPUT_DIR, OUTPUT_FILE), index=False)
