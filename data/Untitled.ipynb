# %%
# import the dependencies
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
import os

# %%
import geopy

# %%
# constants
DATA_DIR = ""

# %%
os.path.join(DATA_DIR,"Snow_Emergency_Grant_Tows_2015.geojson")
# Out:
# 'Snow_Emergency_Grant_Tows_2015.geojson'

# %%
grant_tows = gpd.read_file(os.path.join(DATA_DIR,"Snow_Emergency_Grant_Tows_2015.geojson"))

# %%
grant_tows.head()
# Out:
#    FID             X             Y           Call_Taken  \
# 0    1 -1.038025e+07  5.623291e+06  2015-12-29T00:00:00
# 1    2 -1.038334e+07  5.618287e+06  2015-12-29T00:00:00
# 2    3 -1.038308e+07  5.615996e+06  2015-12-29T00:00:00
# 3    4 -1.038080e+07  5.614751e+06  2015-12-29T00:00:00
# 4    5 -1.038023e+07  5.626288e+06  2015-12-29T00:00:00
#
#                  Location    Day                                      geometry
# 0     2326 Central Ave NE  Day 1  POINT (-93.24740688343616 45.01123618428048)
# 1               618 1ST N  Day 1  POINT (-93.27510825313226 44.97945116173709)
# 2          1824 3rd ave s  Day 1  POINT (-93.27281155185176 44.96488946723947)
# 3  2519 bloomington ave s  Day 1  POINT (-93.25235251858196 44.95697462618004)
# 4     3447 Central Ave NE  Day 1  POINT (-93.24719240972475 45.03026988637581)

# %%
def xcoord (point):
    if point:
        return point.x
    else:
        return None

# %%
gpd.tools.geocode?

# %%
missing_locations = []
for row in grant_tows.itertuples():
    if not row.geometry:
        print(row.Location)
        missing_locations.append(row.Location + ", Minneapolis, MN")
        # print(missing_locations)
# Out:
# chicago ave s/34th st e
# 601 N 7th St
# 350 van white mem
# 279 w 15th st
# 132 w 15th st
# 279 w 15th st
# 160 w 15th
# 19 w 15th st
# 708 VAN WHITE
# 1120 van white ave n
# 1128 van white
# 59 n 4th ave
# 3825 3rd
# 1603 24th AV s
# 525 N 2ND ST
# 14th and washington
# 160 w 15th st
# 1815 noth emerson
# 501 e 15th St
# 1158 van white Blvd n
# 2715 east 50th street
# 2303 9 th sts
# 14 ave se
# 14th ave se 8th st se
# 2586 w 43rd st
# 386 w 15th st
# 2001 S 9th st
# 1215w 26th
# 513
# 510 n 1st st
# 386 w 15th st
# 2811 blaisedale s
# 5044 5th at s
# 2322 butler pl
# 368 w15th st
# 368 w15th st
# 328 w15th
# 160 w 15th st
# 15th and LaSalle
# 875 9th ave s.e.
# 469 W 15th ST
# 160 w 15th st
# 3550 e 46th st
# 1341 n 2nd st
# 10th and washington
# 27 w 15th st
# Se hennepin/18 ave se
# 411 N 2ND ST
# Willow and grant
# 3076 Emerson Abe n Minneapolis
# 507 e 15th
# 2636 Emerson ace n Minneapolis
# University and 8th ave
# 395 2nd st s e
# NE Grand & Lowry
# 528 e 15th st
# ...

# %%
missing_locations
# Out:
# ['chicago ave s/34th st e, Minneapolis, MN',
#  '601 N 7th St, Minneapolis, MN',
#  '350 van white mem, Minneapolis, MN',
#  '279 w 15th st, Minneapolis, MN',
#  '132 w 15th st, Minneapolis, MN',
#  '279 w 15th st, Minneapolis, MN',
#  '160 w 15th, Minneapolis, MN',
#  '19 w 15th st, Minneapolis, MN',
#  '708 VAN WHITE, Minneapolis, MN',
#  '1120 van white ave n, Minneapolis, MN',
#  '1128 van white, Minneapolis, MN',
#  '59 n 4th ave, Minneapolis, MN',
#  '3825 3rd, Minneapolis, MN',
#  '1603 24th AV s, Minneapolis, MN',
#  '525 N 2ND ST, Minneapolis, MN',
#  '14th and washington, Minneapolis, MN',
#  '160 w 15th st, Minneapolis, MN',
#  '1815 noth emerson, Minneapolis, MN',
#  '501 e 15th St, Minneapolis, MN',
#  '1158 van white Blvd n, Minneapolis, MN',
#  '2715 east 50th street, Minneapolis, MN',
#  '2303 9 th sts, Minneapolis, MN',
#  '14 ave se, Minneapolis, MN',
#  '14th ave se 8th st se, Minneapolis, MN',
#  '2586 w 43rd st, Minneapolis, MN',
# ...

# %%
from geopy.geocoders import GoogleV3
geolocator = GoogleV3(api_key="AIzaSyC-_yUJpJLpXWeGuFUQA99hBAwZvffKP5I")

# %%
result = geolocator.geocode('chicago ave s/34th st e, Minneapolis, MN')

# %%
result.latitude
# Out:
# 44.941456

# %%
result.longitude
# Out:
# -93.262657
